# %%
import csv
import pylab as pl
import os 
import json
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib 
import os
import sys
import pandas as pd

# %%
url ="http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=cdda2259-2e72-457a-9c7d-5eee4e74c68f&VehicleMonitoringDetailLevel=calls&LineRef=B52"

# %%
print(url)
# Out:
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=cdda2259-2e72-457a-9c7d-5eee4e74c68f&VehicleMonitoringDetailLevel=calls&LineRef=B52

# %%
df = pd.read_json(url)
df.to_csv("busline.csv")

# %%
response = urllib.urlopen(url)
data = response.read().decode("utf-8")

# %%
dataDict = json.loads(data)

# %%
variable1 = dataDict['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']
variable1
# Out:
# [{'MonitoredVehicleJourney': {'Bearing': 329.60126,
#    'BlockRef': 'MTA NYCT_FP_D8-Sunday_D_FP_70800_B52-115',
#    'DestinationName': 'RIDGEWOOD TERM via GATES',
#    'DestinationRef': 'MTA_801117',
#    'DirectionRef': '0',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-23',
#     'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Sunday-124100_B52_115'},
#    'JourneyPatternRef': 'MTA_B520052',
#    'LineRef': 'MTA NYCT_B52',
#    'Monitored': True,
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-23T21:20:31.854-04:00',
#     'ExpectedDepartureTime': '2018-09-23T21:20:31.854-04:00',
#     'Extensions': {'Distances': {'CallDistanceAlongRoute': 8098.58,
#       'DistanceFromCall': 76.15,
#       'PresentableDistance': 'approaching',
#       'StopsFromCall': 0}},
#     'StopPointName': 'PALMETTO ST/IRVING AV',
#     'StopPointRef': 'MTA_304415',
#     'VisitNumber': 1},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-23T21:20:31.854-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8098.58,
#         'DistanceFromCall': 76.15,
#         'PresentableDistance': 'approaching',
#         'StopsFromCall': 0}},
#       'StopPointName': 'PALMETTO ST/IRVING AV',
#       'StopPointRef': 'MTA_304415'},
#      {'ExpectedArrivalTime': '2018-09-23T21:21:05.422-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8248.54,
#         'DistanceFromCall': 226.12,
#         'PresentableDistance': '1 stop away',
#         'StopsFromCall': 1}},
#       'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#       'StopPointRef': 'MTA_801117'}]},
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_307175',
#    'ProgressRate': 'normalProgress',
#    'PublishedLineName': 'B52',
#    'SituationRef': [],
#    'VehicleLocation': {'Latitude': 40.698185, 'Longitude': -73.912928},
#    'VehicleRef': 'MTA NYCT_3987'},
#   'RecordedAtTime': '2018-09-23T21:20:14.000-04:00'},
#  {'MonitoredVehicleJourney': {'Bearing': 158.48412,
#    'BlockRef': 'MTA NYCT_FP_D8-Sunday_D_FP_67080_B26-14',
#    'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#    'DestinationRef': 'MTA_901463',
#    'DirectionRef': '1',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-23',
#     'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Sunday-123200_B26_14'},
#    'JourneyPatternRef': 'MTA_B520053',
#    'LineRef': 'MTA NYCT_B52',
#    'Monitored': True,
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-23T21:20:59.934-04:00',
#     'ExpectedDepartureTime': '2018-09-23T21:20:59.934-04:00',
#     'Extensions': {'Distances': {'CallDistanceAlongRoute': 6487.03,
#       'DistanceFromCall': 130.66,
#       'PresentableDistance': 'approaching',
#       'StopsFromCall': 0}},
#     'StopPointName': 'FULTON ST/S ELLIOTT PL',
#     'StopPointRef': 'MTA_302427',
#     'VisitNumber': 1},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-23T21:20:59.934-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6487.03,
#         'DistanceFromCall': 130.66,
#         'PresentableDistance': 'approaching',
#         'StopsFromCall': 0}},
#       'StopPointName': 'FULTON ST/S ELLIOTT PL',
#       'StopPointRef': 'MTA_302427'},
#      {'ExpectedArrivalTime': '2018-09-23T21:21:54.752-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6642.98,
#         'DistanceFromCall': 286.6,
#         'PresentableDistance': '1 stop away',
#         'StopsFromCall': 1}},
#       'StopPointName': 'FULTON ST/FT GREENE PL',
#       'StopPointRef': 'MTA_302428'},
#      {'ExpectedArrivalTime': '2018-09-23T21:23:13.552-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6942.37,
#         'DistanceFromCall': 586.0,
#         'PresentableDistance': '2 stops away',
#         'StopsFromCall': 2}},
#       'StopPointName': 'FULTON ST/HUDSON AV',
#       'StopPointRef': 'MTA_302430'},
#      {'ExpectedArrivalTime': '2018-09-23T21:24:35.184-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7193.37,
#         'DistanceFromCall': 837.0,
#         'PresentableDistance': '0.5 miles away',
#         'StopsFromCall': 3}},
#       'StopPointName': 'FULTON ST/BOND ST',
#       'StopPointRef': 'MTA_302431'},
#      {'ExpectedArrivalTime': '2018-09-23T21:25:29.104-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7397.6,
#         'DistanceFromCall': 1041.23,
#         'PresentableDistance': '0.6 miles away',
#         'StopsFromCall': 4}},
#       'StopPointName': 'FULTON ST/DUFFIELD ST',
#       'StopPointRef': 'MTA_307492'},
#      {'ExpectedArrivalTime': '2018-09-23T21:26:20.638-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7605.4,
#         'DistanceFromCall': 1249.03,
#         'PresentableDistance': '0.8 miles away',
#         'StopsFromCall': 5}},
#       'StopPointName': 'FULTON ST/JAY ST',
#       'StopPointRef': 'MTA_302433'},
#      {'ExpectedArrivalTime': '2018-09-23T21:28:22.653-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7931.22,
#         'DistanceFromCall': 1574.84,
#         'PresentableDistance': '1.0 miles away',
#         'StopsFromCall': 6}},
#       'StopPointName': 'JORALEMON ST/COURT ST',
#       'StopPointRef': 'MTA_302434'},
#      {'Extensions': {'Distances': {'CallDistanceAlongRoute': 8065.26,
#         'DistanceFromCall': 1708.89,
#         'PresentableDistance': '1.1 miles away',
#         'StopsFromCall': 7}},
#       'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#       'StopPointRef': 'MTA_306533'},
#      {'ExpectedArrivalTime': '2018-09-23T21:29:14.010-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8096.35,
#         'DistanceFromCall': 1739.98,
#         'PresentableDistance': '1.1 miles away',
#         'StopsFromCall': 8}},
#       'StopPointName': 'CADMAN PZ W/TILLARY ST',
#       'StopPointRef': 'MTA_901463'}]},
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_504965',
#    'ProgressRate': 'normalProgress',
#    'PublishedLineName': 'B52',
#    'SituationRef': [{'SituationSimpleRef': 'MTA NYCT_19929615-c455-4276-bd84-b376be67c288'}],
#    'VehicleLocation': {'Latitude': 40.686119, 'Longitude': -73.974062},
#    'VehicleRef': 'MTA NYCT_6500'},
#   'RecordedAtTime': '2018-09-23T21:20:19.000-04:00'},
#  {'MonitoredVehicleJourney': {'Bearing': 185.87885,
#    'BlockRef': 'MTA NYCT_FP_D8-Sunday_D_FP_74400_B26-17',
#    'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#    'DestinationRef': 'MTA_901463',
#    'DirectionRef': '1',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-23',
#     'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Sunday-125200_B26_17'},
#    'JourneyPatternRef': 'MTA_B520053',
#    'LineRef': 'MTA NYCT_B52',
#    'Monitored': True,
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-23T21:20:35.831-04:00',
#     'ExpectedDepartureTime': '2018-09-23T21:20:35.831-04:00',
#     'Extensions': {'Distances': {'CallDistanceAlongRoute': 6238.78,
#       'DistanceFromCall': 135.47,
#       'PresentableDistance': 'approaching',
#       'StopsFromCall': 0}},
#     'StopPointName': 'GREENE AV/CUMBERLAND ST',
#     'StopPointRef': 'MTA_307577',
#     'VisitNumber': 1},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-23T21:20:35.831-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6238.78,
#         'DistanceFromCall': 135.47,
#         'PresentableDistance': 'approaching',
#         'StopsFromCall': 0}},
#       'StopPointName': 'GREENE AV/CUMBERLAND ST',
#       'StopPointRef': 'MTA_307577'},
#      {'ExpectedArrivalTime': '2018-09-23T21:21:53.606-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6487.03,
#         'DistanceFromCall': 383.72,
#         'PresentableDistance': '1 stop away',
#         'StopsFromCall': 1}},
#       'StopPointName': 'FULTON ST/S ELLIOTT PL',
#       'StopPointRef': 'MTA_302427'},
#      {'ExpectedArrivalTime': '2018-09-23T21:22:48.424-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6642.98,
#         'DistanceFromCall': 539.66,
#         'PresentableDistance': '2 stops away',
#         'StopsFromCall': 2}},
#       'StopPointName': 'FULTON ST/FT GREENE PL',
#       'StopPointRef': 'MTA_302428'},
#      {'ExpectedArrivalTime': '2018-09-23T21:24:07.224-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6942.37,
#         'DistanceFromCall': 839.06,
#         'PresentableDistance': '0.5 miles away',
#         'StopsFromCall': 3}},
#       'StopPointName': 'FULTON ST/HUDSON AV',
#       'StopPointRef': 'MTA_302430'},
#      {'ExpectedArrivalTime': '2018-09-23T21:25:28.856-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7193.37,
#         'DistanceFromCall': 1090.06,
#         'PresentableDistance': '0.7 miles away',
#         'StopsFromCall': 4}},
#       'StopPointName': 'FULTON ST/BOND ST',
#       'StopPointRef': 'MTA_302431'},
#      {'ExpectedArrivalTime': '2018-09-23T21:26:22.776-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7397.6,
#         'DistanceFromCall': 1294.29,
#         'PresentableDistance': '0.8 miles away',
#         'StopsFromCall': 5}},
#       'StopPointName': 'FULTON ST/DUFFIELD ST',
#       'StopPointRef': 'MTA_307492'},
#      {'ExpectedArrivalTime': '2018-09-23T21:27:14.310-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7605.4,
#         'DistanceFromCall': 1502.09,
#         'PresentableDistance': '0.9 miles away',
#         'StopsFromCall': 6}},
#       'StopPointName': 'FULTON ST/JAY ST',
#       'StopPointRef': 'MTA_302433'},
#      {'ExpectedArrivalTime': '2018-09-23T21:29:16.325-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7931.22,
#         'DistanceFromCall': 1827.91,
#         'PresentableDistance': '1.1 miles away',
#         'StopsFromCall': 7}},
#       'StopPointName': 'JORALEMON ST/COURT ST',
#       'StopPointRef': 'MTA_302434'},
#      {'Extensions': {'Distances': {'CallDistanceAlongRoute': 8065.26,
#         'DistanceFromCall': 1961.95,
#         'PresentableDistance': '1.2 miles away',
#         'StopsFromCall': 8}},
#       'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#       'StopPointRef': 'MTA_306533'},
#      {'ExpectedArrivalTime': '2018-09-23T21:30:07.682-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8096.35,
#         'DistanceFromCall': 1993.04,
#         'PresentableDistance': '1.2 miles away',
#         'StopsFromCall': 9}},
#       'StopPointName': 'CADMAN PZ W/TILLARY ST',
#       'StopPointRef': 'MTA_901463'}]},
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_504965',
#    'ProgressRate': 'normalProgress',
#    'PublishedLineName': 'B52',
#    'SituationRef': [{'SituationSimpleRef': 'MTA NYCT_19929615-c455-4276-bd84-b376be67c288'}],
#    'VehicleLocation': {'Latitude': 40.686056, 'Longitude': -73.971217},
#    'VehicleRef': 'MTA NYCT_7296'},
#   'RecordedAtTime': '2018-09-23T21:19:55.000-04:00'},
#  {'MonitoredVehicleJourney': {'Bearing': 6.4354553,
#    'BlockRef': 'MTA NYCT_FP_D8-Sunday_D_FP_65400_B26-12',
#    'DestinationName': 'RIDGEWOOD TERM via GATES',
#    'DestinationRef': 'MTA_801117',
#    'DirectionRef': '0',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-23',
#     'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Sunday-126000_B26_12'},
#    'JourneyPatternRef': 'MTA_B520052',
#    'LineRef': 'MTA NYCT_B52',
#    'Monitored': True,
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-23T21:20:44.683-04:00',
#     'ExpectedDepartureTime': '2018-09-23T21:20:44.683-04:00',
#     'Extensions': {'Distances': {'CallDistanceAlongRoute': 3364.21,
#       'DistanceFromCall': 137.44,
#       'PresentableDistance': 'approaching',
#       'StopsFromCall': 0}},
#     'StopPointName': 'GREENE AV/CLASSON AV',
#     'StopPointRef': 'MTA_307552',
#     'VisitNumber': 1},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-23T21:20:44.683-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3364.21,
#         'DistanceFromCall': 137.44,
#         'PresentableDistance': 'approaching',
#         'StopsFromCall': 0}},
#       'StopPointName': 'GREENE AV/CLASSON AV',
#       'StopPointRef': 'MTA_307552'},
#      {'ExpectedArrivalTime': '2018-09-23T21:21:49.083-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3595.03,
#         'DistanceFromCall': 368.26,
#         'PresentableDistance': '1 stop away',
#         'StopsFromCall': 1}},
#       'StopPointName': 'FRANKLIN AV/GREENE AV',
#       'StopPointRef': 'MTA_307553'},
#      {'ExpectedArrivalTime': '2018-09-23T21:22:46.175-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3843.44,
#         'DistanceFromCall': 616.67,
#         'PresentableDistance': '2 stops away',
#         'StopsFromCall': 2}},
#       'StopPointName': 'GATES AV/FRANKLIN AV',
#       'StopPointRef': 'MTA_307674'},
#      {'ExpectedArrivalTime': '2018-09-23T21:23:38.478-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4027.09,
#         'DistanceFromCall': 800.32,
#         'PresentableDistance': '3 stops away',
#         'StopsFromCall': 3}},
#       'StopPointName': 'GATES AV/BEDFORD AV',
#       'StopPointRef': 'MTA_307675'},
#      {'ExpectedArrivalTime': '2018-09-23T21:24:30.550-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4291.16,
#         'DistanceFromCall': 1064.39,
#         'PresentableDistance': '0.7 miles away',
#         'StopsFromCall': 4}},
#       'StopPointName': 'GATES AV/NOSTRAND AV',
#       'StopPointRef': 'MTA_307676'},
#      {'ExpectedArrivalTime': '2018-09-23T21:26:03.626-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4616.54,
#         'DistanceFromCall': 1389.76,
#         'PresentableDistance': '0.9 miles away',
#         'StopsFromCall': 5}},
#       'StopPointName': 'GATES AV/MARCY AV',
#       'StopPointRef': 'MTA_307677'},
#      {'ExpectedArrivalTime': '2018-09-23T21:27:09.026-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4866.0,
#         'DistanceFromCall': 1639.23,
#         'PresentableDistance': '1.0 miles away',
#         'StopsFromCall': 6}},
#       'StopPointName': 'GATES AV/TOMPKINS AV',
#       'StopPointRef': 'MTA_307678'},
#      {'ExpectedArrivalTime': '2018-09-23T21:28:17.935-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5103.34,
#         'DistanceFromCall': 1876.57,
#         'PresentableDistance': '1.2 miles away',
#         'StopsFromCall': 7}},
#       'StopPointName': 'GATES AV/THROOP AV',
#       'StopPointRef': 'MTA_307679'},
#      {'ExpectedArrivalTime': '2018-09-23T21:29:22.335-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5342.21,
#         'DistanceFromCall': 2115.44,
#         'PresentableDistance': '1.3 miles away',
#         'StopsFromCall': 8}},
#       'StopPointName': 'GATES AV/MARCUS GARVEY BL',
#       'StopPointRef': 'MTA_307680'},
#      {'ExpectedArrivalTime': '2018-09-23T21:30:39.244-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5591.01,
#         'DistanceFromCall': 2364.23,
#         'PresentableDistance': '1.5 miles away',
#         'StopsFromCall': 9}},
#       'StopPointName': 'GATES AV/LEWIS AV',
#       'StopPointRef': 'MTA_307681'},
#      {'ExpectedArrivalTime': '2018-09-23T21:31:54.053-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5842.65,
#         'DistanceFromCall': 2615.88,
#         'PresentableDistance': '1.6 miles away',
#         'StopsFromCall': 10}},
#       'StopPointName': 'GATES AV/STUYVESANT AV',
#       'StopPointRef': 'MTA_307682'},
#      {'ExpectedArrivalTime': '2018-09-23T21:33:23.395-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6092.05,
#         'DistanceFromCall': 2865.27,
#         'PresentableDistance': '1.8 miles away',
#         'StopsFromCall': 11}},
#       'StopPointName': 'GATES AV/MALCOLM X BL',
#       'StopPointRef': 'MTA_307683'},
#      {'ExpectedArrivalTime': '2018-09-23T21:34:22.009-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6337.9,
#         'DistanceFromCall': 3111.12,
#         'PresentableDistance': '1.9 miles away',
#         'StopsFromCall': 12}},
#       'StopPointName': 'GATES AV/PATCHEN AV',
#       'StopPointRef': 'MTA_307684'},
#      {'ExpectedArrivalTime': '2018-09-23T21:35:14.473-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6572.3,
#         'DistanceFromCall': 3345.53,
#         'PresentableDistance': '2.1 miles away',
#         'StopsFromCall': 13}},
#       'StopPointName': 'GATES AV/RALPH AV',
#       'StopPointRef': 'MTA_307901'},
#      {'ExpectedArrivalTime': '2018-09-23T21:36:01.673-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6734.12,
#         'DistanceFromCall': 3507.35,
#         'PresentableDistance': '2.2 miles away',
#         'StopsFromCall': 14}},
#       'StopPointName': 'GATES AV/BROADWAY',
#       'StopPointRef': 'MTA_307686'},
#      {'ExpectedArrivalTime': '2018-09-23T21:37:39.401-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6977.66,
#         'DistanceFromCall': 3750.88,
#         'PresentableDistance': '2.3 miles away',
#         'StopsFromCall': 15}},
#       'StopPointName': 'GATES AV/BUSHWICK AV',
#       'StopPointRef': 'MTA_307687'},
#      {'ExpectedArrivalTime': '2018-09-23T21:38:30.725-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7146.91,
#         'DistanceFromCall': 3920.13,
#         'PresentableDistance': '2.4 miles away',
#         'StopsFromCall': 16}},
#       'StopPointName': 'GATES AV/EVERGREEN AV',
#       'StopPointRef': 'MTA_307688'},
#      {'ExpectedArrivalTime': '2018-09-23T21:39:36.925-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7388.47,
#         'DistanceFromCall': 4161.7,
#         'PresentableDistance': '2.6 miles away',
#         'StopsFromCall': 17}},
#       'StopPointName': 'GATES AV/CENTRAL AV',
#       'StopPointRef': 'MTA_307689'},
#      {'ExpectedArrivalTime': '2018-09-23T21:40:26.125-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7591.7,
#         'DistanceFromCall': 4364.93,
#         'PresentableDistance': '2.7 miles away',
#         'StopsFromCall': 18}},
#       'StopPointName': 'GATES AV/WILSON AV',
#       'StopPointRef': 'MTA_307690'},
#      {'ExpectedArrivalTime': '2018-09-23T21:41:28.325-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7797.59,
#         'DistanceFromCall': 4570.81,
#         'PresentableDistance': '2.8 miles away',
#         'StopsFromCall': 19}},
#       'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#       'StopPointRef': 'MTA_307691'},
#      {'ExpectedArrivalTime': '2018-09-23T21:42:38.891-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8098.58,
#         'DistanceFromCall': 4871.81,
#         'PresentableDistance': '3.0 miles away',
#         'StopsFromCall': 20}},
#       'StopPointName': 'PALMETTO ST/IRVING AV',
#       'StopPointRef': 'MTA_304415'},
#      {'ExpectedArrivalTime': '2018-09-23T21:43:12.459-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8248.54,
#         'DistanceFromCall': 5021.77,
#         'PresentableDistance': '3.1 miles away',
#         'StopsFromCall': 21}},
#       'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#       'StopPointRef': 'MTA_801117'}]},
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_307175',
#    'ProgressRate': 'normalProgress',
#    'PublishedLineName': 'B52',
#    'SituationRef': [],
#    'VehicleLocation': {'Latitude': 40.687258, 'Longitude': -73.960897},
#    'VehicleRef': 'MTA NYCT_6494'},
#   'RecordedAtTime': '2018-09-23T21:20:08.000-04:00'},
#  {'MonitoredVehicleJourney': {'Bearing': 44.40111,
#    'BlockRef': 'MTA NYCT_FP_D8-Sunday_D_FP_63240_B52-114',
#    'DestinationName': 'RIDGEWOOD TERM via GATES',
#    'DestinationRef': 'MTA_801117',
#    'DirectionRef': '0',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-23',
#     'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Sunday-122600_B52_114'},
#    'JourneyPatternRef': 'MTA_B520052',
#    'LineRef': 'MTA NYCT_B52',
#    'Monitored': True,
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-23T21:20:58.672-04:00',
#     'ExpectedDepartureTime': '2018-09-23T21:20:58.672-04:00',
#     'Extensions': {'Distances': {'CallDistanceAlongRoute': 6977.66,
#       'DistanceFromCall': 161.16,
#       'PresentableDistance': '< 1 stop away',
#       'StopsFromCall': 0}},
#     'StopPointName': 'GATES AV/BUSHWICK AV',
#     'StopPointRef': 'MTA_307687',
#     'VisitNumber': 1},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-23T21:20:58.672-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6977.66,
#         'DistanceFromCall': 161.16,
#         'PresentableDistance': '< 1 stop away',
#         'StopsFromCall': 0}},
#       'StopPointName': 'GATES AV/BUSHWICK AV',
#       'StopPointRef': 'MTA_307687'},
#      {'ExpectedArrivalTime': '2018-09-23T21:21:49.996-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7146.91,
#         'DistanceFromCall': 330.41,
#         'PresentableDistance': '1 stop away',
#         'StopsFromCall': 1}},
#       'StopPointName': 'GATES AV/EVERGREEN AV',
#       'StopPointRef': 'MTA_307688'},
#      {'ExpectedArrivalTime': '2018-09-23T21:22:56.196-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7388.47,
#         'DistanceFromCall': 571.98,
#         'PresentableDistance': '2 stops away',
#         'StopsFromCall': 2}},
#       'StopPointName': 'GATES AV/CENTRAL AV',
#       'StopPointRef': 'MTA_307689'},
#      {'ExpectedArrivalTime': '2018-09-23T21:23:45.396-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7591.7,
#         'DistanceFromCall': 775.21,
#         'PresentableDistance': '3 stops away',
#         'StopsFromCall': 3}},
#       'StopPointName': 'GATES AV/WILSON AV',
#       'StopPointRef': 'MTA_307690'},
#      {'ExpectedArrivalTime': '2018-09-23T21:24:47.596-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7797.59,
#         'DistanceFromCall': 981.09,
#         'PresentableDistance': '0.6 miles away',
#         'StopsFromCall': 4}},
#       'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#       'StopPointRef': 'MTA_307691'},
#      {'ExpectedArrivalTime': '2018-09-23T21:25:58.162-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8098.58,
#         'DistanceFromCall': 1282.08,
#         'PresentableDistance': '0.8 miles away',
#         'StopsFromCall': 5}},
#       'StopPointName': 'PALMETTO ST/IRVING AV',
#       'StopPointRef': 'MTA_304415'},
#      {'ExpectedArrivalTime': '2018-09-23T21:26:31.730-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8248.54,
#         'DistanceFromCall': 1432.05,
#         'PresentableDistance': '0.9 miles away',
#         'StopsFromCall': 6}},
#       'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#       'StopPointRef': 'MTA_801117'}]},
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_307175',
#    'ProgressRate': 'normalProgress',
#    'PublishedLineName': 'B52',
#    'SituationRef': [],
#    'VehicleLocation': {'Latitude': 40.689997, 'Longitude': -73.921574},
#    'VehicleRef': 'MTA NYCT_7297'},
#   'RecordedAtTime': '2018-09-23T21:19:54.000-04:00'}]

# %%
##MonitoredVehicleJourney

index = 0
df_all=pd.DataFrame(columns=['latitude','Longitude','Busstop','Stopstatus'])
for k in variable1:
    k = k['MonitoredVehicleJourney']
    latitude = k['VehicleLocation']['Latitude']
    Longitude = k['VehicleLocation']['Longitude']
    Busstop = k['OnwardCalls']['OnwardCall'][0]['StopPointName']
    Stopstatus= k['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance']
    index+=1 
    df_all.loc[index] = [latitude,Longitude,Busstop,Stopstatus]
    print (latitude,Longitude,Busstop,Stopstatus)
# Out:
# 40.698185 -73.912928 PALMETTO ST/IRVING AV approaching
# 40.686119 -73.974062 FULTON ST/S ELLIOTT PL approaching
# 40.686056 -73.971217 GREENE AV/CUMBERLAND ST approaching
# 40.687258 -73.960897 GREENE AV/CLASSON AV approaching
# 40.689997 -73.921574 GATES AV/BUSHWICK AV < 1 stop away

# %%
# df = pd.DataFrame(data=[[latitude,Longitude,Busstop,Stopstatus]])

# %%
df_all
# Out:
#     latitude  Longitude                  Busstop     Stopstatus
# 1  40.698185 -73.912928    PALMETTO ST/IRVING AV    approaching
# 2  40.686119 -73.974062   FULTON ST/S ELLIOTT PL    approaching
# 3  40.686056 -73.971217  GREENE AV/CUMBERLAND ST    approaching
# 4  40.687258 -73.960897     GREENE AV/CLASSON AV    approaching
# 5  40.689997 -73.921574     GATES AV/BUSHWICK AV  < 1 stop away

# %%
df_all.to_csv('B52.csv')
